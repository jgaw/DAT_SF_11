# %%
#Import libraries for doing image analysis
from skimage.io import imread
from skimage.transform import resize
from skimage import transform as tf
from sklearn.ensemble import RandomForestClassifier as RF
import glob
import os
from sklearn import cross_validation as cv
from sklearn.cross_validation import StratifiedKFold as KFold
from sklearn.metrics import classification_report
from matplotlib import pyplot as plt
from matplotlib import colors
from pylab import cm
from skimage import segmentation
from skimage.morphology import watershed
from skimage import measure
from skimage import morphology
import numpy as np
import pandas as pd
from scipy import ndimage
from skimage.feature import peak_local_max


# make graphics inline
# %matplotlib inline

# %%
# !pwd
# Out:
# /Users/jeremiah/dropbox/dat_sf_11

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
directory_names = list(set(glob.glob(os.path.join("/Users/jeremiah/dropbox/DATA/competition_data","/Users/jeremiah/dropbox/DATA/train", "*"))\
 ).difference(set(glob.glob(os.path.join("/Users/jeremiah/dropbox/DATA/competition_data","/Users/jeremiah/dropbox/DATA/train","*.*")))))

# %%
# Example image
# This example was chosen for because it has two noncontinguous pieces
# that will make the segmentation example more illustrative
example_file = glob.glob(os.path.join(directory_names[8],"*.jpg"))[9]
print example_file
im = imread(example_file, as_grey=True)
plt.imshow(im, cmap=cm.gray)
plt.show()
# Out:
# /Users/jeremiah/dropbox/DATA/train/artifacts/103437.jpg

# %%
from skimage import filter
# Compute the Canny filter for two values of si
edges1 = filter.sobel(im)
edges2 = filter.roberts(im)

fig, (ax0, ax1, ax2) = plt.subplots(ncols=3, figsize=(15,30))

ax0.imshow(edges2, cmap=plt.cm.gray)
ax0.set_title('Roberts Edge Detection')
ax0.axis('off')

ax1.imshow(edges1, cmap=plt.cm.gray)
ax1.set_title('Sobel Edge Detection')
ax1.axis('off')

ax2.imshow(im, cmap=plt.cm.gray)
ax2.set_title('Normal Image')
ax2.axis('off')

plt.show()

# %%
# First we threshold the image by only taking values greater than the mean to reduce noise in the image
# to use later as a mask
f = plt.figure(figsize=(12,3))
imthr = im.copy()
imthr = np.where(im > np.mean(im),0.,1.0)
sub1 = plt.subplot(1,4,1)
plt.imshow(im, cmap=cm.gray)
sub1.set_title("Original Image")

sub2 = plt.subplot(1,4,2)
plt.imshow(imthr, cmap=cm.gray_r)
sub2.set_title("Thresholded Image")

imdilated = morphology.dilation(imthr, np.ones((4,4)))
sub3 = plt.subplot(1, 4, 3)
plt.imshow(imdilated, cmap=cm.gray_r)
sub3.set_title("Dilated Image")

labels = measure.label(imdilated)
labels = imthr*labels
labels = labels.astype(int)
sub4 = plt.subplot(1, 4, 4)
sub4.set_title("Labeled Image")
plt.imshow(labels)

# %%
def getMinorMajorRatio(image):
    image = image.copy()
    # Create the thresholded image to eliminate some of the background
    imagethr = np.where(image > np.mean(image),0.,1.0)

    #Dilate the image
    imdilated = morphology.dilation(imagethr, np.ones((4,4)))

    # Create the label list
    label_list = measure.label(imdilated)
    label_list = imagethr*label_list
    label_list = label_list.astype(int)
    
    region_list = measure.regionprops(label_list)
    maxregion = getLargestRegion(region_list, label_list, imagethr)
    
    # guard against cases where the segmentation fails by providing zeros
    ratio = 0.0
    if ((not maxregion is None) and  (maxregion.major_axis_length != 0.0)):
        ratio = 0.0 if maxregion is None else  maxregion.minor_axis_length*1.0 / maxregion.major_axis_length
    return ratio

# calculate common region properties for each region within the segmentation
regions = measure.regionprops(labels)
# find the largest nonzero region

def getLargestRegion(props=regions, labelmap=labels, imagethres=imthr):
    regionmaxprop = None
    for regionprop in props:
        # check to see if the region is at least 50% nonzero
        if sum(imagethres[labelmap == regionprop.label])*1.0/regionprop.area < 0.50:
            continue
        if regionmaxprop is None:
            regionmaxprop = regionprop
        if regionmaxprop.filled_area < regionprop.filled_area:
            regionmaxprop = regionprop
    return regionmaxprop

# %%
# Rescale the images and create the combined metrics and training labels

#get the total training images
numberofImages = 0
for folder in directory_names:
    for fileNameDir in os.walk(folder):   
        for fileName in fileNameDir[2]:
             # Only read in the images
            if fileName[-4:] != ".jpg":
              continue
            numberofImages += 1

# We'll rescale the images to be 25x25
maxPixel = 25
imageSize = maxPixel * maxPixel
num_rows = numberofImages # one row for each image in the training dataset
num_features = imageSize + 1 # for our ratio

# X is the feature vector with one row of features per image
# consisting of the pixel values and our metric
X = np.zeros((num_rows, num_features), dtype=float)
# y is the numeric class label 
y = np.zeros((num_rows))

files = []
# Generate training data
i = 0    
label = 0
# List of string of class names
namesClasses = list()

print "Reading images"
# Navigate through the list of directories
for folder in directory_names:
    # Append the string class name for each class
    currentClass = folder.split(os.pathsep)[-1]
    namesClasses.append(currentClass)
    for fileNameDir in os.walk(folder):   
        for fileName in fileNameDir[2]:
            # Only read in the images
            if fileName[-4:] != ".jpg":
              continue
            
            # Read in the images and create the features
            nameFileImage = "{0}{1}{2}".format(fileNameDir[0], os.sep, fileName)            
            image = imread(nameFileImage, as_grey=True)
            files.append(nameFileImage)
            axisratio = getMinorMajorRatio(image)
            image = filter.sobel(resize(image, (maxPixel, maxPixel)))
            
            # Store the rescaled image pixels and the axis ratio
            X[i, 0:imageSize] = np.reshape(image, (1, imageSize))
            X[i, imageSize] = axisratio
            
            # Store the classlabel
            y[i] = label
            i += 1
            # report progress for each 5% done  
            report = [int((j+1)*num_rows/20.) for j in range(20)]
            if i in report: print np.ceil(i *100.0 / num_rows), "% done"
    label += 1
# Out:
# Reading images
# 5.0
#  % done
# 10.0
#  % done
# 15.0
#  % done
# 20.0
#  % done
# 25.0
#  % done
# 30.0
#  % done
# 35.0
#  % done
# 40.0
#  % done
# 45.0
#  % done
# 50.0
#  % done
# 55.0
#  % done
# 60.0
#  % done
# 65.0
#  % done
# 70.0
#  % done
# 75.0
#  % done
# 80.0
#  % done
# 85.0
#  % done
# 90.0
#  % done
# 95.0
#  % done
# 100.0
#  % done

# %%
kf = KFold(y, n_folds=5)
y_pred = y * 0
for train, test in kf:
    X_train, X_test, y_train, y_test = X[train,:], X[test,:], y[train], y[test]
    clf = RF(n_estimators=100, n_jobs=-1)
    clf.fit(X_train, y_train)
    y_pred[test] = clf.predict(X_test)
print classification_report(y, y_pred, target_names=namesClasses)
# Out:
#                                                                                   precision    recall  f1-score   support
#
#                            /Users/jeremiah/dropbox/DATA/train/acantharia_protist       0.53      0.90      0.67       889
#                 /Users/jeremiah/dropbox/DATA/train/acantharia_protist_big_center       0.00      0.00      0.00        13
#                       /Users/jeremiah/dropbox/DATA/train/acantharia_protist_halo       0.83      0.07      0.13        71
#                                     /Users/jeremiah/dropbox/DATA/train/amphipods       0.00      0.00      0.00        49
#                 /Users/jeremiah/dropbox/DATA/train/appendicularian_fritillaridae       0.00      0.00      0.00        16
#                       /Users/jeremiah/dropbox/DATA/train/appendicularian_s_shape       0.34      0.48      0.40       696
#                  /Users/jeremiah/dropbox/DATA/train/appendicularian_slight_curve       0.37      0.45      0.40       532
#                      /Users/jeremiah/dropbox/DATA/train/appendicularian_straight       0.19      0.02      0.04       242
#                                     /Users/jeremiah/dropbox/DATA/train/artifacts       0.55      0.79      0.65       393
#                                /Users/jeremiah/dropbox/DATA/train/artifacts_edge       0.85      0.68      0.76       170
#                       /Users/jeremiah/dropbox/DATA/train/chaetognath_non_sagitta       0.55      0.71      0.62       815
#                             /Users/jeremiah/dropbox/DATA/train/chaetognath_other       0.41      0.77      0.54      1934
#                           /Users/jeremiah/dropbox/DATA/train/chaetognath_sagitta       0.43      0.24      0.31       694
#                                /Users/jeremiah/dropbox/DATA/train/chordate_type1       0.66      0.52      0.58        77
#                              /Users/jeremiah/dropbox/DATA/train/copepod_calanoid       0.44      0.63      0.52       681
#                         /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_eggs       0.79      0.25      0.38       173
#                    /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_eucalanus       0.93      0.14      0.24        96
#                    /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_flatheads       0.31      0.02      0.04       178
#               /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_frillyAntennae       1.00      0.05      0.09        63
#                        /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_large       0.65      0.29      0.40       286
#     /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_large_side_antennatucked       0.48      0.12      0.20       106
#                     /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_octomoms       0.00      0.00      0.00        49
#           /Users/jeremiah/dropbox/DATA/train/copepod_calanoid_small_longantennae       0.86      0.22      0.35        87
#                     /Users/jeremiah/dropbox/DATA/train/copepod_cyclopoid_copilia       0.00      0.00      0.00        30
#                     /Users/jeremiah/dropbox/DATA/train/copepod_cyclopoid_oithona       0.56      0.70      0.62       899
#                /Users/jeremiah/dropbox/DATA/train/copepod_cyclopoid_oithona_eggs       0.62      0.80      0.70      1189
#                                 /Users/jeremiah/dropbox/DATA/train/copepod_other       0.00      0.00      0.00        24
#                              /Users/jeremiah/dropbox/DATA/train/crustacean_other       0.35      0.09      0.14       201
#                             /Users/jeremiah/dropbox/DATA/train/ctenophore_cestid       0.28      0.04      0.08       113
#              /Users/jeremiah/dropbox/DATA/train/ctenophore_cydippid_no_tentacles       0.00      0.00      0.00        42
#                 /Users/jeremiah/dropbox/DATA/train/ctenophore_cydippid_tentacles       0.00      0.00      0.00        53
#                             /Users/jeremiah/dropbox/DATA/train/ctenophore_lobate       1.00      0.08      0.15        38
#                                      /Users/jeremiah/dropbox/DATA/train/decapods       0.00      0.00      0.00        55
#                                 /Users/jeremiah/dropbox/DATA/train/detritus_blob       0.17      0.05      0.08       363
#                          /Users/jeremiah/dropbox/DATA/train/detritus_filamentous       0.18      0.03      0.05       394
#                                /Users/jeremiah/dropbox/DATA/train/detritus_other       0.23      0.32      0.27       914
#                           /Users/jeremiah/dropbox/DATA/train/diatom_chain_string       0.68      0.92      0.78       519
#                             /Users/jeremiah/dropbox/DATA/train/diatom_chain_tube       0.39      0.45      0.42       500
#          /Users/jeremiah/dropbox/DATA/train/echinoderm_larva_pluteus_brittlestar       0.60      0.17      0.26        36
#                /Users/jeremiah/dropbox/DATA/train/echinoderm_larva_pluteus_early       0.51      0.39      0.44        92
#                /Users/jeremiah/dropbox/DATA/train/echinoderm_larva_pluteus_typeC       0.89      0.30      0.45        80
#               /Users/jeremiah/dropbox/DATA/train/echinoderm_larva_pluteus_urchin       0.53      0.32      0.40        88
#           /Users/jeremiah/dropbox/DATA/train/echinoderm_larva_seastar_bipinnaria       0.57      0.54      0.56       385
#         /Users/jeremiah/dropbox/DATA/train/echinoderm_larva_seastar_brachiolaria       0.52      0.83      0.64       536
#      /Users/jeremiah/dropbox/DATA/train/echinoderm_seacucumber_auricularia_larva       0.00      0.00      0.00        96
#                                 /Users/jeremiah/dropbox/DATA/train/echinopluteus       0.00      0.00      0.00        27
#                                        /Users/jeremiah/dropbox/DATA/train/ephyra       0.00      0.00      0.00        14
#                                   /Users/jeremiah/dropbox/DATA/train/euphausiids       0.67      0.04      0.08       136
#                             /Users/jeremiah/dropbox/DATA/train/euphausiids_young       0.00      0.00      0.00        38
#                                  /Users/jeremiah/dropbox/DATA/train/fecal_pellet       0.34      0.30      0.32       511
#                         /Users/jeremiah/dropbox/DATA/train/fish_larvae_deep_body       0.00      0.00      0.00        10
#                      /Users/jeremiah/dropbox/DATA/train/fish_larvae_leptocephali       0.00      0.00      0.00        31
#                       /Users/jeremiah/dropbox/DATA/train/fish_larvae_medium_body       0.55      0.25      0.34        85
#                        /Users/jeremiah/dropbox/DATA/train/fish_larvae_myctophids       0.45      0.51      0.48       114
#                         /Users/jeremiah/dropbox/DATA/train/fish_larvae_thin_body       0.40      0.03      0.06        64
#                    /Users/jeremiah/dropbox/DATA/train/fish_larvae_very_thin_body       0.00      0.00      0.00        16
#                                     /Users/jeremiah/dropbox/DATA/train/heteropod       0.00      0.00      0.00        10
#                          /Users/jeremiah/dropbox/DATA/train/hydromedusae_aglaura       0.00      0.00      0.00       127
#               /Users/jeremiah/dropbox/DATA/train/hydromedusae_bell_and_tentacles       0.43      0.08      0.13        75
#                              /Users/jeremiah/dropbox/DATA/train/hydromedusae_h15       0.52      0.43      0.47        35
#                        /Users/jeremiah/dropbox/DATA/train/hydromedusae_haliscera       0.45      0.55      0.49       229
#         /Users/jeremiah/dropbox/DATA/train/hydromedusae_haliscera_small_sideview       0.00      0.00      0.00         9
#                          /Users/jeremiah/dropbox/DATA/train/hydromedusae_liriope       0.00      0.00      0.00        19
#                       /Users/jeremiah/dropbox/DATA/train/hydromedusae_narco_dark       0.00      0.00      0.00        23
#                      /Users/jeremiah/dropbox/DATA/train/hydromedusae_narco_young       0.33      0.13      0.18       336
#                     /Users/jeremiah/dropbox/DATA/train/hydromedusae_narcomedusae       0.33      0.01      0.01       132
#                            /Users/jeremiah/dropbox/DATA/train/hydromedusae_other       0.00      0.00      0.00        12
#                     /Users/jeremiah/dropbox/DATA/train/hydromedusae_partial_dark       0.53      0.21      0.30       190
#                           /Users/jeremiah/dropbox/DATA/train/hydromedusae_shapeA       0.48      0.76      0.59       412
#            /Users/jeremiah/dropbox/DATA/train/hydromedusae_shapeA_sideview_small       0.35      0.08      0.13       274
#                           /Users/jeremiah/dropbox/DATA/train/hydromedusae_shapeB       0.48      0.20      0.28       150
#                     /Users/jeremiah/dropbox/DATA/train/hydromedusae_sideview_big       0.00      0.00      0.00        76
#                         /Users/jeremiah/dropbox/DATA/train/hydromedusae_solmaris       0.40      0.76      0.52       703
#                      /Users/jeremiah/dropbox/DATA/train/hydromedusae_solmundella       0.93      0.30      0.45       123
#                            /Users/jeremiah/dropbox/DATA/train/hydromedusae_typeD       0.00      0.00      0.00        43
#         /Users/jeremiah/dropbox/DATA/train/hydromedusae_typeD_bell_and_tentacles       0.80      0.36      0.49        56
#                            /Users/jeremiah/dropbox/DATA/train/hydromedusae_typeE       0.00      0.00      0.00        14
#                            /Users/jeremiah/dropbox/DATA/train/hydromedusae_typeF       0.56      0.16      0.25        61
#                   /Users/jeremiah/dropbox/DATA/train/invertebrate_larvae_other_A       0.00      0.00      0.00        14
#                   /Users/jeremiah/dropbox/DATA/train/invertebrate_larvae_other_B       0.00      0.00      0.00        24
#                             /Users/jeremiah/dropbox/DATA/train/jellies_tentacles       0.43      0.07      0.12       141
#                                    /Users/jeremiah/dropbox/DATA/train/polychaete       0.60      0.02      0.04       131
#                           /Users/jeremiah/dropbox/DATA/train/protist_dark_center       0.00      0.00      0.00       108
#                           /Users/jeremiah/dropbox/DATA/train/protist_fuzzy_olive       0.71      0.76      0.74       372
#                             /Users/jeremiah/dropbox/DATA/train/protist_noctiluca       0.49      0.52      0.51       625
#                                 /Users/jeremiah/dropbox/DATA/train/protist_other       0.37      0.65      0.47      1172
#                                  /Users/jeremiah/dropbox/DATA/train/protist_star       0.88      0.39      0.54       113
#                            /Users/jeremiah/dropbox/DATA/train/pteropod_butterfly       0.54      0.06      0.12       108
#                        /Users/jeremiah/dropbox/DATA/train/pteropod_theco_dev_seq       0.00      0.00      0.00        13
#                             /Users/jeremiah/dropbox/DATA/train/pteropod_triangle       1.00      0.02      0.03        65
#                             /Users/jeremiah/dropbox/DATA/train/radiolarian_chain       0.32      0.04      0.07       287
#                            /Users/jeremiah/dropbox/DATA/train/radiolarian_colony       0.40      0.10      0.16       158
#                             /Users/jeremiah/dropbox/DATA/train/shrimp-like_other       0.00      0.00      0.00        52
#                               /Users/jeremiah/dropbox/DATA/train/shrimp_caridean       0.50      0.10      0.17        49
#                            /Users/jeremiah/dropbox/DATA/train/shrimp_sergestidae       0.83      0.23      0.36       153
#                                   /Users/jeremiah/dropbox/DATA/train/shrimp_zoea       0.52      0.16      0.24       174
#            /Users/jeremiah/dropbox/DATA/train/siphonophore_calycophoran_abylidae       0.30      0.10      0.15       212
#    /Users/jeremiah/dropbox/DATA/train/siphonophore_calycophoran_rocketship_adult       0.43      0.10      0.16       135
#    /Users/jeremiah/dropbox/DATA/train/siphonophore_calycophoran_rocketship_young       0.40      0.31      0.35       483
#       /Users/jeremiah/dropbox/DATA/train/siphonophore_calycophoran_sphaeronectes       0.41      0.16      0.23       179
#  /Users/jeremiah/dropbox/DATA/train/siphonophore_calycophoran_sphaeronectes_stem       0.00      0.00      0.00        57
# /Users/jeremiah/dropbox/DATA/train/siphonophore_calycophoran_sphaeronectes_young       0.47      0.08      0.13       247
#                      /Users/jeremiah/dropbox/DATA/train/siphonophore_other_parts       0.00      0.00      0.00        29
#                          /Users/jeremiah/dropbox/DATA/train/siphonophore_partial       0.00      0.00      0.00        30
#                        /Users/jeremiah/dropbox/DATA/train/siphonophore_physonect       0.17      0.01      0.01       128
#                  /Users/jeremiah/dropbox/DATA/train/siphonophore_physonect_young       0.00      0.00      0.00        21
#                                    /Users/jeremiah/dropbox/DATA/train/stomatopod       0.00      0.00      0.00        24
#                    /Users/jeremiah/dropbox/DATA/train/tornaria_acorn_worm_larvae       1.00      0.11      0.19        38
#                          /Users/jeremiah/dropbox/DATA/train/trichodesmium_bowtie       0.44      0.68      0.53       708
#                        /Users/jeremiah/dropbox/DATA/train/trichodesmium_multiple       1.00      0.02      0.04        54
#                            /Users/jeremiah/dropbox/DATA/train/trichodesmium_puff       0.70      0.91      0.79      1979
#                            /Users/jeremiah/dropbox/DATA/train/trichodesmium_tuft       0.40      0.51      0.45       678
#                            /Users/jeremiah/dropbox/DATA/train/trochophore_larvae       0.00      0.00      0.00        29
#                             /Users/jeremiah/dropbox/DATA/train/tunicate_doliolid       0.38      0.11      0.18       439
#                       /Users/jeremiah/dropbox/DATA/train/tunicate_doliolid_nurse       0.27      0.09      0.14       417
#                              /Users/jeremiah/dropbox/DATA/train/tunicate_partial       0.56      0.95      0.70       352
#                                 /Users/jeremiah/dropbox/DATA/train/tunicate_salp       0.52      0.74      0.61       236
#                          /Users/jeremiah/dropbox/DATA/train/tunicate_salp_chains       0.50      0.01      0.03        73
#                     /Users/jeremiah/dropbox/DATA/train/unknown_blobs_and_smudges       0.36      0.15      0.21       317
#                                /Users/jeremiah/dropbox/DATA/train/unknown_sticks       0.31      0.09      0.13       175
#                          /Users/jeremiah/dropbox/DATA/train/unknown_unclassified       0.04      0.00      0.00       425
#
#                                                                      avg / total       0.45      0.48      0.42     30336

# %%
def multiclass_log_loss(y_true, y_pred, eps=1e-15):
    """Multi class version of Logarithmic Loss metric.
    https://www.kaggle.com/wiki/MultiClassLogLoss

    Parameters
    ----------
    y_true : array, shape = [n_samples]
            true class, intergers in [0, n_classes - 1)
    y_pred : array, shape = [n_samples, n_classes]

    Returns
    -------
    loss : float
    """
    predictions = np.clip(y_pred, eps, 1 - eps)

    # normalize row sums to 1
    predictions /= predictions.sum(axis=1)[:, np.newaxis]

    actual = np.zeros(y_pred.shape)
    n_samples = actual.shape[0]
    actual[np.arange(n_samples), y_true.astype(int)] = 1
    vectsum = np.sum(actual * np.log(predictions))
    loss = -1.0 / n_samples * vectsum
    return loss

# %%
# Get the probability predictions for computing the log-loss function
kf = KFold(y, n_folds=5)
# prediction probabilities number of samples, by number of classes
y_pred = np.zeros((len(y),len(set(y))))
for train, test in kf:
    X_train, X_test, y_train, y_test = X[train,:], X[test,:], y[train], y[test]
    clf = RF(n_estimators=100, n_jobs=-1)
    clf.fit(X_train, y_train)
    y_pred[test] = clf.predict_proba(X_test)

# %%
multiclass_log_loss(y, y_pred)
# Out:
# 3.6296958098419041

# %%
X_train, X_test, y_train, y_test = cv.train_test_split(X, y, test_size = 0.33, random_state=42)

# %%
import neurolab as nl

# 2 layers with 225 inputs 50 neurons in hidden\input layer and 10 in output
# for 3 layers use some thet: nl.net.newff([[0, .1]]*225, [50, 40, 10])
net = nl.net.newff([[0, .1]]*626, [5, 121])
net.trainf = nl.train.train_bfgs

e = net.train(X_train, y_train, show=1, epochs=100, goal=0.0001)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-122-7dfb15220eeb> in <module>()
#       6 net.trainf = nl.train.train_bfgs
#       7
# ----> 8 e = net.train(X_train, y_train, show=1, epochs=100, goal=0.0001)
#
# /Users/jeremiah/anaconda/lib/python2.7/site-packages/neurolab/core.pyc in train(self, *args, **kwargs)
#     163
#     164         """
# --> 165         return self.trainf(self, *args, **kwargs)
#     166
#     167     def reset(self):
#
# /Users/jeremiah/anaconda/lib/python2.7/site-packages/neurolab/core.pyc in __call__(self, net, input, target, **kwargs)
#     324         if target is not None:
#     325             target = np.asfarray(target)
# --> 326             assert target.ndim == 2
#     327             assert target.shape[1] == net.co
#     328             assert target.shape[0] == input.shape[0]
#
# AssertionError:

# %%
out = net.sim(X_test)

# %%
len(namesClasses)
# Out:
# 121

# %%
X_train.shape
# Out:
# (20325, 626)

# %%
import pybrain
